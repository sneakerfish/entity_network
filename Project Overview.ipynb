# %%
import spacy

nlp = spacy.load("en_core_web_lg")

doc = nlp("This is a sentence about President Biden.")
for item in doc.ents:
    print(item)
# Out:
# Biden

# %%
import newspaper

# %%
cnn_paper = newspaper.build('http://cnn.com')
for article in cnn_paper.articles:
    print(article.url)
# Out:
# http://cnn.com/business/media
# http://cnn.com/travel/news
# http://cnn.com/2021/05/05/china/australia-china-war-military-mic-intl-hnk/index.html
# http://cnn.com/style/article/future-smart-home-ambient-technology/index.html
# http://cnn.com/style/article/crochet-culture-internet-trend/index.html
# http://cnn.com/style/article/red-carpet-fashion-at-the-2021-oscars/index.html
# http://cnn.com/style/article/jon-m-chu-in-the-heights-hyphenated/index.html
# http://cnn.com/style/article/frieze-new-york-2021-returns/index.html
# http://cnn.com/style/article/benin-bronzes-germany-restitution/index.html
# http://cnn.com/style/article/halston-ewan-mcgregor-netflix/index.html
# http://cnn.com/style/article/alber-elbaz-designer-dies-intl/index.html
# http://cnn.com/style/article/adrienne-raquel-onyx-fotografiska/index.html
# http://cnn.com/style/article/arthur-drooker-city-hall-photos/index.html
# http://cnn.com/style/article/old-ireland-color-photos-breslin/index.html
# ...

# %%
article = cnn_paper.articles[25]
article.download()
article.parse()
article.text
# Out:
# 'Written by Oscar Holland, CNN\n\nIt was 1996 when the young poet Tugsjargal Munkherdene heard American hip-hop for the first time.\n\nFour years earlier, Mongolia\'s Soviet-aligned government had fallen, opening the country to a fresh wave of cultural imports. The easing of state censorship heralded a new era of free expression. It also meant that G-funk, boom bap and gangster rap soon arrived on the airwaves -- including the track that made a lasting impression on the then-teenage Munkherdene: Dr. Dre and Snoop Dogg\'s "187 On an Undercover Cop."\n\n"I realized I could put my poems on a beat like them, and I started writing rap music," he recalled in a video interview from his studio in Ulaanbaatar, Mongolia\'s capital.\n\nGrowing up in one of Ulaanbaatar\'s impoverished ger districts, Munkherdene could empathize with the kind of urban hardship chronicled in the music he idolized. Comprised largely of semi-permanent tents (or gers, the Mongolian word for yurts), these sprawling out
# ...

# %%
nyt_paper = newspaper.build('http://nytimes.com')
for article in nyt_paper.articles:
    print(article.url)
# Out:
# http://nytimes.com/2021/05/05/briefing/olympic-games-japan-covid-summer.html
# http://nytimes.com/2021/05/05/podcasts/the-daily/japan-birthrate-ageing-population.html
# https://www.nytimes.com/2021/05/05/technology/facebook-trump-ban-upheld.html
# https://www.nytimes.com/2021/05/05/technology/What-Is-the-Facebook-Oversight-Board.html
# https://www.nytimes.com/2021/05/04/us/politics/barr-trump-obstruction-russia-inquiry.html
# https://www.nytimes.com/live/2021/05/05/us/joe-biden-news/
# https://www.nytimes.com/2021/05/05/us/politics/democrats-house-retirements.html
# https://www.nytimes.com/2021/05/05/us/voting-rights-bill-legal.html
# https://www.nytimes.com/2021/05/04/us/politics/justin-lafferty-tennessee-three-fifths-compromise.html
# https://www.nytimes.com/2021/05/05/us/us-birthrate-falls-covid.html
# https://www.nytimes.com/2021/05/05/world/europe/coronavirus-covax-vaccination.html
# https://www.nytimes.com/live/2021/05/05/world/covid-vaccine-coronavirus-cases/
# ...

# %%
article = nyt_paper.articles[25]
article.download()
article.parse()
article.text
# Out:
# 'Was that dip matched by concurrent weight gain among Americans who suddenly couldn’t make it to their weekly weigh-ins or stock up on their meal-replacement shakes? Depends whose data you believe. A study published in the journal Obesity found a global decline in some healthy behaviors: Respondents ate more processed food and exercised less. And a recent survey from the market research firm Ipsos found that about a third of Americans said they had gained weight during the pandemic.\n\nBut research from a company that makes internet-connected scales, Withings, painted a different picture. The French company analyzed data from five million smart scales, hybrid smartwatches and smart thermometers, and found that people actually lost weight in 2020, or were more likely than in other years to hit their weight-loss goals, if they had them. (Of course, those who own such devices are a self-selecting group that likely were trying to lose weight.)\n\nIn any case, the weight-loss industry isn
# ...
